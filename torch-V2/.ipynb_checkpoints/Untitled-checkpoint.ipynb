# %%
import numpy as np
import torch

# %%
def create_W2(beta, J, h):
    # 計算 cosh 和 sinh 部分
    cosh = np.cosh(beta * J)
    sinh = np.sinh(beta * J)
    
    # 建立矩陣
    W_s = torch.tensor([
        [np.sqrt(cosh) * np.exp(beta * h/2), np.sqrt(sinh) * np.exp(beta * h/2)],
        [np.sqrt(cosh) * np.exp(-beta * h/2), -np.sqrt(sinh) * np.exp(-beta * h/2)]
    ])
    
    return W_s

def create_W(beta, J, h):
    # 計算 cosh 和 sinh 部分
    cosh_plus = np.cosh(beta * J + beta * h)
    sinh_plus = np.sinh(beta * J + beta * h)
    cosh_minus = np.cosh(beta * J - beta * h)
    sinh_minus = np.sinh(beta * J - beta * h)
    
    # 建立矩陣
    W_s = torch.tensor([
        [np.sqrt(cosh_plus), np.sqrt(sinh_plus)],
        [np.sqrt(cosh_minus), -np.sqrt(sinh_minus)]
    ])
    
    return W_s


temp = 4
beta = 1/temp
J = 1.0     # 自旋耦合
h = 0.1     # 外場

W_s = create_W(beta, J, h)
print(W_s)

W_s = create_W2(beta, J, h)
print(W_s)
# Out:
# tensor([[ 1.0188,  0.5277],
#         [ 1.0126, -0.4763]], dtype=torch.float64)
# tensor([[ 1.0284,  0.5089],
#         [ 1.0030, -0.4964]], dtype=torch.float64)

# %%
temp = 4
beta = 1/temp
J = 1.0     # 自旋耦合
h = 0.1     # 外場

def get_M(beta, J = 1):
    # 計算 cosh 和 sinh 部分
    cosh = np.cosh(beta * J)
    sinh = np.sinh(beta * J)
    
    # 建立矩陣
    W_s = torch.tensor([
        [np.sqrt(cosh), np.sqrt(sinh)],
        [np.sqrt(cosh), -np.sqrt(sinh)]
    ])
    
    return W_s

M = get_M(beta)
print(M)
# Out:
# tensor([[ 1.0156,  0.5026],
#         [ 1.0156, -0.5026]], dtype=torch.float64)

# %%
def get_W(beta, J=1, h=0):
    """
    Calculate the matrix W based on beta, J, and h.
    
    Parameters:
        beta (float): Inverse temperature.
        J (float): Interaction strength (default is 1).
        h (float): External field strength (default is 0).

    Returns:
        torch.Tensor: Matrix W.
    """
    sq_cosh = np.sqrt(np.cosh(beta * J))
    sq_sinh = np.sqrt(np.sinh(beta * J))
    W = torch.tensor([
        [sq_cosh, sq_sinh],
        [sq_cosh, -sq_sinh]
    ])
    return W


#可能Wh是正確的包含h的作法
def get_Wh(beta, J, h):
    """
    Calculate the matrix Wh incorporating the external field h.
    
    Parameters:
        beta (float): Inverse temperature.
        J (float): Interaction strength.
        h (float): External field strength.

    Returns:
        torch.Tensor: Matrix Wh.
    """
    cosh = np.cosh(beta * J)
    sinh = np.sinh(beta * J)

    Wh = torch.tensor([
        [np.sqrt(cosh) * np.exp(beta * h / 2), np.sqrt(sinh) * np.exp(beta * h / 2)],
        [np.sqrt(cosh) * np.exp(-beta * h / 2), -np.sqrt(sinh) * np.exp(-beta * h / 2)]
    ])
    return Wh


# 上左右下
def get_T_bare(beta, J=1, h=0, get_W=get_W):
    """
    Calculate the bare transfer matrix T_bare.
    
    Parameters:
        beta (float): Inverse temperature.
        J (float): Interaction strength (default is 1).
        h (float): External field strength (default is 0).
        get_W (callable): Function to calculate W or Wh (default is get_W).

    Returns:
        torch.Tensor: Bare transfer matrix T_bare.
    """
    W = get_W(beta, J=J, h=h)
    T_bare = torch.einsum('ai,aj,ak,al->ijkl', W, W, W, W)
    return T_bare

# %%
print(get_T_bare(1/4))
print(get_T_bare(1/3))
print(get_T_bare(1/2))

print(get_T_bare(1/4, h=-0.1, get_W = get_Wh))
# Out:
# tensor([[[[2.1276, 0.0000],
#           [0.0000, 0.5211]],
#
#          [[0.0000, 0.5211],
#           [0.5211, 0.0000]]],
#
#
#         [[[0.0000, 0.5211],
#           [0.5211, 0.0000]],
#
#          [[0.5211, 0.0000],
#           [0.0000, 0.1276]]]], dtype=torch.float64)
# tensor([[[[2.2306, 0.0000],
#           [0.0000, 0.7172]],
#
#          [[0.0000, 0.7172],
#           [0.7172, 0.0000]]],
#
#
#         [[[0.0000, 0.7172],
#           [0.7172, 0.0000]],
#
#          [[0.7172, 0.0000],
#           [0.0000, 0.2306]]]], dtype=torch.float64)
# tensor([[[[2.5431, 0.0000],
#           [0.0000, 1.1752]],
#
#          [[0.0000, 1.1752],
#           [1.1752, 0.0000]]],
#
#
#         [[[0.0000, 1.1752],
#           [1.1752, 0.0000]],
#
#          [[1.1752, 0.0000],
#           [0.0000, 0.5431]]]], dtype=torch.float64)
# tensor([[[[ 2.1303, -0.0527],
#           [-0.0527,  0.5217]],
#
#          [[-0.0527,  0.5217],
#           [ 0.5217, -0.0129]]],
#
#
#         [[[-0.0527,  0.5217],
#           [ 0.5217, -0.0129]],
#
#          [[ 0.5217, -0.0129],
#           [-0.0129,  0.1278]]]], dtype=torch.float64)

# %%
def merge_y(Tup, Tdn, combine=False, trace=False):
    if trace:
        Tmerge = torch.einsum('abcd,defa->becf', Tup, Tdn)
        
        if combine:
            shape = Tmerge.shape
            Tmerge = Tmerge.contiguous().view(shape[0] * shape[1], shape[2] * shape[3])
    else:
        Tmerge = torch.einsum('abcd,defg->abecfg', Tup, Tdn)
        
        if combine:
            shape = Tmerge.shape
            Tmerge = Tmerge.contiguous().view(shape[0], shape[1] * shape[2], shape[3] * shape[4], shape[5])
            
    return Tmerge

# %%
MaxL = 4
Temp = np.linspace(2.26,4,100)
W = np.ones((MaxL+1,len(Temp),2))
E = np.ones((MaxL+1,len(Temp),2))
Tc = 2/np.log(1+np.sqrt(2))

# %%
TL = get_T_bare(4)
TL_Trace = merge_y(TL,TL,True,True)

# %%
# %%time

for i,temp in enumerate(Temp):
    T_bare = get_T_bare(1/temp)
    TL = T_bare
    for j in range(2,MaxL+1):
        TL_Trace = merge_y(TL,TL,True,True)
        eigvals, eigvecs = torch.linalg.eigh(TL_Trace)
        W[j,i,:] = eigvals[-2:]
        del TL_Trace
        if j != MaxL:
            TL = merge_y(TL,TL,True)
E = -np.log(W)
Corr_len = 1/(E[:,:,-2]-E[:,:,-1])
# Out:
# CPU times: user 2.28 s, sys: 1.76 s, total: 4.04 s
# Wall time: 686 ms
# <timed exec>:12: RuntimeWarning: divide by zero encountered in divide

# %%
Corr_len
# Out:
# array([[        inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf],
#        [        inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf,
#                 inf,         inf,         inf,         inf,         inf],
#        [ 2.31472413,  2.27871701,  2.24380586,  2.20994608,  2.17709529,
#          2.14521318,  2.11426145,  2.08420362,  2.05500501,  2.02663254,
#          1.99905473,  1.97224157,  1.94616442,  1.92079599,  1.8961102 ,
#          1.87208218,  1.84868816,  1.82590544,  1.8037123 ,  1.78208799,
#          1.76101266,  1.74046731,  1.72043374,  1.70089454,  1.68183303,
#          1.66323321,  1.64507977,  1.62735799,  1.61005379,  1.59315363,
#          1.57664454,  1.56051403,  1.54475015,  1.52934137,  1.51427666,
#          1.49954538,  1.4851373 ,  1.47104261,  1.45725184,  1.44375588,
#          1.43054598,  1.41761369,  1.4049509 ,  1.39254976,  1.38040272,
#          1.36850253,  1.35684215,  1.34541482,  1.33421402,  1.32323345,
#          1.31246703,  1.30190889,  1.29155337,  1.28139498,  1.27142845,
#          1.26164866,  1.25205067,  1.24262971,  1.23338117,  1.22430057,
#          1.2153836 ,  1.20662607,  1.19802394,  1.1895733 ,  1.18127035,
#          1.17311142,  1.16509296,  1.15721151,  1.14946375,  1.14184643,
#          1.13435641,  1.12699067,  1.11974623,  1.11262026,  1.10560996,
#          1.09871265,  1.09192572,  1.08524662,  1.0786729 ,  1.07220216,
#          1.06583209,  1.05956042,  1.05338496,  1.04730359,  1.04131424,
#          1.03541489,  1.02960359,  1.02387845,  1.0182376 ,  1.01267925,
#          1.00720165,  1.00180311,  0.99648196,  0.9912366 ,  0.98606545,
#          0.98096698,  0.97593972,  0.97098221,  0.96609304,  0.96127084],
#        [ 5.02625749,  4.85956748,  4.70166801,  4.55199404,  4.41002191,
#          4.275266  ,  4.14727569,  4.02563251,  3.90994765,  3.79985957,
#          3.69503194,  3.59515164,  3.49992702,  3.40908621,  3.3223757 ,
#          3.23955891,  3.16041496,  3.08473748,  3.01233358,  2.94302287,
#          2.87663652,  2.81301647,  2.75201465,  2.69349226,  2.63731915,
#          2.58337317,  2.53153968,  2.48171099,  2.43378588,  2.38766918,
#          2.34327137,  2.3005082 ,  2.2593003 ,  2.21957292,  2.18125559,
#          2.14428183,  2.10858894,  2.07411771,  2.04081222,  2.00861965,
#          1.97749003,  1.94737611,  1.91823319,  1.89001895,  1.86269328,
#          1.83621821,  1.81055771,  1.78567763,  1.76154556,  1.73813072,
#          1.71540389,  1.69333731,  1.6719046 ,  1.65108064,  1.63084158,
#          1.61116468,  1.5920283 ,  1.57341185,  1.55529569,  1.53766109,
#          1.52049019,  1.50376598,  1.48747218,  1.47159328,  1.45611446,
#          1.44102154,  1.42630099,  1.41193985,  1.39792574,  1.38424681,
#          1.37089172,  1.35784958,  1.34511001,  1.33266303,  1.32049906,
#          1.30860896,  1.29698391,  1.28561549,  1.27449559,  1.26361644,
#          1.25297056,  1.24255079,  1.23235021,  1.2223622 ,  1.21258039,
#          1.20299863,  1.19361102,  1.18441189,  1.17539576,  1.16655736,
#          1.15789161,  1.14939363,  1.1410587 ,  1.13288228,  1.12485998,
#          1.11698756,  1.10926096,  1.10167623,  1.09422957,  1.08691731],
#        [10.49301405,  9.79221325,  9.15813659,  8.58346738,  8.06175924,
#          7.58732625,  7.15514774,  6.76078585,  6.40031375,  6.07025324,
#          5.76752034,  5.48937778,  5.23339351,  4.99740433,  4.77948415,
#          4.57791609,  4.391168  ,  4.21787105,  4.05680085,  3.90686089,
#          3.76706798,  3.63653943,  3.51448178,  3.40018087,  3.29299303,
#          3.19233742,  3.09768917,  3.00857337,  2.92455973,  2.84525787,
#          2.77031318,  2.69940307,  2.63223372,  2.56853716,  2.50806867,
#          2.45060449,  2.39593974,  2.34388663,  2.29427277,  2.24693977,
#          2.20174186,  2.1585448 ,  2.11722476,  2.07766741,  2.03976707,
#          2.00342593,  1.9685534 ,  1.93506546,  1.90288408,  1.87193676,
#          1.84215607,  1.81347918,  1.78584754,  1.75920654,  1.73350514,
#          1.70869564,  1.68473344,  1.66157672,  1.63918633,  1.61752552,
#          1.59655979,  1.57625672,  1.55658582,  1.53751841,  1.51902745,
#          1.50108749,  1.48367449,  1.46676577,  1.4503399 ,  1.43437664,
#          1.41885683,  1.40376232,  1.38907595,  1.37478143,  1.36086333,
#          1.34730698,  1.33409848,  1.32122461,  1.30867279,  1.29643108,
#          1.2844881 ,  1.272833  ,  1.26145548,  1.25034567,  1.23949421,
#          1.22889212,  1.21853086,  1.20840226,  1.19849851,  1.18881215,
#          1.17933603,  1.17006332,  1.16098748,  1.15210224,  1.14340159,
#          1.13487978,  1.12653128,  1.1183508 ,  1.11033325,  1.10247374]])

# %%
def merge_y_truncate(Tup, Tdn, dcut, niter = 10):
    if ((Tup.shape[1] * Tdn.shape[1]) < dcut):
        return merge_y(Tup, Tdn, True)
    Tmerge_pure = torch.einsum('abcd,defg,achi,iejg->bfhj', Tup, Tdn, Tup, Tdn)
    Tmerge_pure_shape = Tmerge_pure.shape
    Tmerge_pure = Tmerge_pure.contiguous().view(
        Tmerge_pure_shape[0] * Tmerge_pure_shape[1],Tmerge_pure_shape[2] * Tmerge_pure_shape[3]
    )
    U, S, V = torch.svd_lowrank(Tmerge_pure, q=dcut, niter=niter)
    U = U.view(Tmerge_pure_shape[0], Tmerge_pure_shape[1], dcut)
    Tmerge = torch.einsum('abcd,defg,bfh,cei->ahig', Tup, Tdn, U, U)
    return Tmerge

# %%
temp = 2
dcut = 8

TL = get_T_bare(1/temp)
print(TL)
TL = merge_y_truncate(TL,TL,dcut)
print(TL)
TL = merge_y_truncate(TL,TL,dcut)
print(TL)
TL = merge_y_truncate(TL,TL,dcut)
print(TL)
TL = merge_y_truncate(TL,TL,dcut)
print(TL)
# Out:
# tensor([[[[2.5431, 0.0000],
#           [0.0000, 1.1752]],
#
#          [[0.0000, 1.1752],
#           [1.1752, 0.0000]]],
#
#
#         [[[0.0000, 1.1752],
#           [1.1752, 0.0000]],
#
#          [[1.1752, 0.0000],
#           [0.0000, 0.5431]]]], dtype=torch.float64)
# tensor([[[[6.4673, 0.0000],
#           [0.0000, 2.9886],
#           [0.0000, 1.3811],
#           [1.3811, 0.0000]],
#
#          [[0.0000, 2.9886],
#           [2.9886, 0.0000],
#           [1.3811, 0.0000],
#           [0.0000, 0.6382]],
#
#          [[0.0000, 1.3811],
#           [1.3811, 0.0000],
#           [2.9886, 0.0000],
#           [0.0000, 1.3811]],
#
#          [[1.3811, 0.0000],
#           [0.0000, 0.6382],
#           [0.0000, 1.3811],
#           [1.3811, 0.0000]]],
#
#
#         [[[0.0000, 1.3811],
#           [1.3811, 0.0000],
#           [2.9886, 0.0000],
#           [0.0000, 1.3811]],
#
#          [[1.3811, 0.0000],
#           [0.0000, 0.6382],
#           [0.0000, 1.3811],
#           [1.3811, 0.0000]],
#
#          [[2.9886, 0.0000],
#           [0.0000, 1.3811],
#           [0.0000, 0.6382],
#           [0.6382, 0.0000]],
#
#          [[0.0000, 1.3811],
#           [1.3811, 0.0000],
#           [0.6382, 0.0000],
#           [0.0000, 0.2949]]]], dtype=torch.float64)
# tensor([[[[ 5.0663e+01,  2.3231e-15],
#           [-1.9559e-16, -2.5350e+01],
#           [ 2.5199e-16, -1.0346e+01],
#           [ 2.9661e+00,  5.7416e-17],
#           [-3.4832e-15, -3.3733e+00],
#           [-5.3735e-13,  6.1270e-14],
#           [ 4.3970e-08,  1.5924e+00],
#           [ 8.7246e-01, -4.9527e-09]],
#
#          [[-1.9559e-16, -2.5350e+01],
#           [ 4.1166e+01, -1.4057e-15],
#           [ 4.8568e-14, -5.5851e-16],
#           [ 1.7089e-16,  6.9221e+00],
#           [-2.8227e+00,  7.1510e-14],
#           [ 4.9950e-14,  4.1533e+00],
#           [ 1.1366e-11,  4.8240e-08],
#           [ 1.6763e-09,  8.5735e-01]],
#
#          [[ 2.5199e-16, -1.0346e+01],
#           [ 4.6360e-14, -5.5851e-16],
#           [ 2.0162e+01, -1.8683e-16],
#           [-7.1950e-18, -1.0694e+01],
#           [-1.1881e-14, -9.4042e-15],
#           [ 9.6435e-17, -1.8708e-12],
#           [ 8.1743e-01,  1.5462e-07],
#           [ 4.8917e-13,  2.3086e-01]],
#
#          [[ 2.9661e+00,  5.7416e-17],
#           [ 1.7089e-16,  6.9221e+00],
#           [-7.1950e-18, -1.0694e+01],
#           [ 1.6556e+01,  7.0621e-17],
#           [-1.3601e-14, -7.7389e-01],
#           [-1.6980e-12,  1.8646e-14],
#           [ 1.3947e-07, -3.1578e-01],
#           [-6.1311e-01, -2.1607e-08]],
#
#          [[-3.4832e-15, -3.3733e+00],
#           [-2.8227e+00,  7.1510e-14],
#           [-1.0421e-14, -9.4042e-15],
#           [-1.3601e-14, -7.7389e-01],
#           [ 1.2834e+01, -1.9514e-13],
#           [-4.2760e-14, -6.6095e+00],
#           [ 6.4985e-11, -3.2229e-07],
#           [ 9.5820e-09, -1.4682e-01]],
#
#          [[-5.3654e-13,  6.1270e-14],
#           [ 4.9950e-14,  4.1533e+00],
#           [ 9.6435e-17, -1.8715e-12],
#           [-1.6974e-12,  1.8646e-14],
#           [-4.2760e-14, -6.6095e+00],
#           [ 1.0271e+01,  2.2598e-13],
#           [ 5.3262e-16,  1.5453e-10],
#           [ 5.7577e-14,  2.2799e-08]],
#
#          [[ 4.3970e-08,  1.5924e+00],
#           [ 1.1367e-11,  4.8240e-08],
#           [ 8.1743e-01,  1.5462e-07],
#           [ 1.3947e-07, -3.1578e-01],
#           [ 6.4987e-11, -3.2229e-07],
#           [ 5.3262e-16,  1.5453e-10],
#           [ 9.5272e+00,  1.6018e-08],
#           [-4.7933e-09,  4.7945e+00]],
#
#          [[ 8.7246e-01, -4.9527e-09],
#           [ 1.6763e-09,  8.5735e-01],
#           [ 4.8917e-13,  2.3086e-01],
#           [-6.1311e-01, -2.1607e-08],
#           [ 9.5820e-09, -1.4682e-01],
#           [ 5.7760e-14,  2.2799e-08],
#           [-4.7933e-09,  4.7945e+00],
#           [ 7.7562e+00,  1.6964e-09]]],
#
#
#         [[[ 1.8134e-15,  1.1943e+01],
#           [-2.5350e+01, -3.2565e-16],
#           [ 1.0346e+01,  2.3612e-16],
#           [-2.2342e-16, -9.6539e+00],
#           [-3.3733e+00, -1.1779e-14],
#           [ 6.1158e-14, -2.1709e-12],
#           [-1.5924e+00,  1.7826e-07],
#           [-4.9546e-09, -1.3879e+00]],
#
#          [[-2.5350e+01, -3.2565e-16],
#           [-1.3906e-15,  1.5664e+01],
#           [ 4.3849e-17,  6.2997e-14],
#           [ 6.9221e+00, -4.7167e-16],
#           [-8.0647e-14,  4.0411e+00],
#           [-4.1533e+00, -6.8294e-14],
#           [ 4.8240e-08, -1.1980e-10],
#           [ 8.5735e-01, -1.7665e-08]],
#
#          [[ 1.0346e+01,  2.3612e-16],
#           [ 4.3849e-17,  5.9696e-14],
#           [ 1.8628e-16, -8.9781e+00],
#           [ 1.0694e+01, -8.3262e-17],
#           [ 9.3441e-15,  1.1612e-14],
#           [ 1.8708e-12,  4.8049e-17],
#           [-1.5462e-07,  4.5766e-01],
#           [-2.3086e-01,  2.7446e-13]],
#
#          [[-2.2342e-16, -9.6539e+00],
#           [ 6.9221e+00, -4.7167e-16],
#           [ 1.0694e+01, -8.3262e-17],
#           [ 2.4774e-17, -3.9721e+00],
#           [-7.7389e-01, -1.5520e-14],
#           [ 1.8156e-14, -2.7479e-12],
#           [ 3.1578e-01,  2.2612e-07],
#           [-2.1606e-08,  5.2164e-01]],
#
#          [[-3.3733e+00, -1.1779e-14],
#           [-8.0647e-14,  4.0411e+00],
#           [ 9.3441e-15,  1.2693e-14],
#           [-7.7389e-01, -1.5520e-14],
#           [ 2.8910e-13, -2.5761e+00],
#           [ 6.6095e+00, -4.8198e-14],
#           [-3.2229e-07,  2.2904e-10],
#           [-1.4682e-01,  3.3772e-08]],
#
#          [[ 6.1158e-14, -2.1702e-12],
#           [-4.1533e+00, -6.8294e-14],
#           [ 1.8714e-12,  4.8049e-17],
#           [ 1.8156e-14, -2.7494e-12],
#           [ 6.6095e+00, -4.8198e-14],
#           [-2.2598e-13, -4.7462e+00],
#           [-1.5453e-10, -1.8931e-17],
#           [-2.2799e-08,  2.3250e-14]],
#
#          [[-1.5924e+00,  1.7826e-07],
#           [ 4.8240e-08, -1.1980e-10],
#           [-1.5462e-07,  4.5766e-01],
#           [ 3.1578e-01,  2.2612e-07],
#           [-3.2229e-07,  2.2904e-10],
#           [-1.5453e-10, -1.8931e-17],
#           [-1.6018e-08, -2.3459e+00],
#           [-4.7945e+00, -1.8403e-09]],
#
#          [[-4.9546e-09, -1.3879e+00],
#           [ 8.5735e-01, -1.7665e-08],
#           [-2.3086e-01,  2.7446e-13],
#           [-2.1606e-08,  5.2164e-01],
#           [-1.4682e-01,  3.3772e-08],
#           [-2.2799e-08,  2.3703e-14],
#           [-4.7945e+00, -1.8403e-09],
#           [ 1.6849e-09, -2.9157e+00]]]], dtype=torch.float64)
# tensor([[[[ 2.9524e+03, -3.7701e-07],
#           [ 8.1243e-09,  1.4602e+03],
#           [-1.3722e-07,  6.1151e+02],
#           [-1.2601e+02, -1.6952e-06],
#           [ 8.5355e-08,  3.7025e+02],
#           [-1.3672e-06,  1.0128e-06],
#           [ 1.0378e-02, -2.8282e+02],
#           [ 1.2336e+02,  7.7326e-03]],
#
#          [[ 8.1243e-09,  1.4602e+03],
#           [ 2.7550e+03,  3.9757e-08],
#           [-3.3744e-11,  2.0246e-06],
#           [ 1.2136e-08,  5.0809e+02],
#           [-1.6888e+02, -7.2110e-08],
#           [-1.7012e-06,  4.2936e+02],
#           [ 6.3767e-02, -8.4218e-03],
#           [-2.8562e-03, -2.0352e+02]],
#
#          [[-1.3722e-07,  6.1151e+02],
#           [-3.3795e-11,  2.0246e-06],
#           [ 1.7257e+03, -5.8869e-06],
#           [-6.2303e-07, -8.8027e+02],
#           [-1.2110e-09, -8.9501e-07],
#           [ 5.7245e-09, -5.9102e-01],
#           [ 8.9237e+01, -8.4591e-02],
#           [-3.8835e-04, -2.0694e+01]],
#
#          [[-1.2601e+02, -1.6952e-06],
#           [ 1.2136e-08,  5.0809e+02],
#           [-6.2303e-07, -8.8027e+02],
#           [ 1.6152e+03,  5.4953e-06],
#           [-3.4415e-07, -4.9582e+01],
#           [ 5.5673e-06,  7.7315e-06],
#           [-3.9985e-02, -3.7105e+01],
#           [ 7.8761e+01, -1.4964e-02]],
#
#          [[ 8.5355e-08,  3.7025e+02],
#           [-1.6888e+02, -7.2110e-08],
#           [-1.2111e-09, -8.9501e-07],
#           [-3.4415e-07, -4.9582e+01],
#           [ 1.2645e+03,  3.0307e-06],
#           [-2.5647e-06, -6.4570e+02],
#           [ 1.0147e-01,  1.1236e-01],
#           [ 1.1237e-03,  3.2749e+01]],
#
#          [[-1.3672e-06,  1.0128e-06],
#           [-1.7012e-06,  4.2936e+02],
#           [ 5.7245e-09, -5.9102e-01],
#           [ 5.5673e-06,  7.7315e-06],
#           [-2.5647e-06, -6.4570e+02],
#           [ 1.1696e+03, -1.5431e-05],
#           [-7.1252e-04, -2.5951e+00],
#           [ 1.0555e-03,  1.3933e-02]],
#
#          [[ 1.0378e-02, -2.8282e+02],
#           [ 6.3767e-02, -8.4218e-03],
#           [ 8.9237e+01, -8.4591e-02],
#           [-3.9985e-02, -3.7105e+01],
#           [ 1.0147e-01,  1.1236e-01],
#           [-7.1252e-04, -2.5951e+00],
#           [ 9.5315e+02, -9.0078e-03],
#           [-1.5000e-03, -4.8809e+02]],
#
#          [[ 1.2336e+02,  7.7326e-03],
#           [-2.8562e-03, -2.0352e+02],
#           [-3.8835e-04, -2.0694e+01],
#           [ 7.8761e+01, -1.4964e-02],
#           [ 1.1237e-03,  3.2749e+01],
#           [ 1.0555e-03,  1.3933e-02],
#           [-1.5000e-03, -4.8809e+02],
#           [ 8.9661e+02,  4.9344e-03]]],
#
#
#         [[[ 1.5573e-07,  6.5885e+02],
#           [ 1.4602e+03, -1.1693e-08],
#           [-6.1151e+02,  2.3019e-06],
#           [ 1.6943e-06,  5.7692e+02],
#           [ 3.7025e+02,  5.5443e-07],
#           [ 1.0490e-06, -9.0165e-06],
#           [ 2.8279e+02,  6.4270e-02],
#           [ 5.2716e-03, -2.5203e+02]],
#
#          [[ 1.4602e+03, -1.1693e-08],
#           [ 1.5786e-07,  8.2951e+02],
#           [ 1.9776e-06, -9.5890e-11],
#           [ 5.0809e+02,  2.5375e-08],
#           [-1.7228e-08,  4.0408e+02],
#           [-4.2936e+02,  7.3484e-06],
#           [-1.2474e-02, -2.8164e-01],
#           [-2.0352e+02, -3.4375e-03]],
#
#          [[-6.1151e+02,  2.3019e-06],
#           [ 1.9776e-06, -9.5834e-11],
#           [ 5.8322e-06, -6.3866e+02],
#           [ 8.8027e+02,  8.2742e-07],
#           [ 5.2220e-07, -1.4584e-09],
#           [-5.9104e-01, -3.7818e-09],
#           [ 8.4782e-02,  9.2582e+01],
#           [ 2.0694e+01, -4.0394e-04]],
#
#          [[ 1.6943e-06,  5.7692e+02],
#           [ 5.0809e+02,  2.5375e-08],
#           [ 8.8027e+02,  8.2742e-07],
#           [-5.5516e-06, -3.0033e+02],
#           [-4.9582e+01, -8.3622e-07],
#           [ 7.7395e-06,  1.3998e-05],
#           [ 3.6441e+01, -1.0170e-01],
#           [-1.5284e-02, -1.0081e+02]],
#
#          [[ 3.7025e+02,  5.5443e-07],
#           [-1.7228e-08,  4.0408e+02],
#           [ 5.2220e-07, -1.4581e-09],
#           [-4.9582e+01, -8.3622e-07],
#           [ 7.1699e-07, -1.8782e+02],
#           [ 6.4570e+02, -8.1583e-06],
#           [ 1.1185e-01,  3.5778e-01],
#           [ 3.2750e+01,  1.7717e-02]],
#
#          [[ 1.0490e-06, -9.0165e-06],
#           [-4.2936e+02,  7.3484e-06],
#           [-5.9104e-01, -3.7818e-09],
#           [ 7.7395e-06,  1.3998e-05],
#           [ 6.4570e+02, -8.1583e-06],
#           [ 1.5440e-05, -4.8600e+02],
#           [-3.2084e+00, -4.1416e-04],
#           [-1.3908e-02,  6.1302e-04]],
#
#          [[ 2.8279e+02,  6.4270e-02],
#           [-1.2474e-02, -2.8164e-01],
#           [ 8.4782e-02,  9.2582e+01],
#           [ 3.6441e+01, -1.0170e-01],
#           [ 1.1185e-01,  3.5778e-01],
#           [-3.2084e+00, -4.1416e-04],
#           [ 1.0498e-02, -2.7469e+02],
#           [ 4.8805e+02,  2.4263e-03]],
#
#          [[ 5.2716e-03, -2.5203e+02],
#           [-2.0352e+02, -3.4375e-03],
#           [ 2.0694e+01, -4.0394e-04],
#           [-1.5284e-02, -1.0081e+02],
#           [ 3.2750e+01,  1.7717e-02],
#           [-1.3908e-02,  6.1302e-04],
#           [ 4.8805e+02,  2.4263e-03],
#           [-3.5730e-03, -2.4107e+02]]]], dtype=torch.float64)
# tensor([[[[ 1.0566e+07, -1.8000e+02],
#           [-2.0190e+00, -5.2372e+06],
#           [ 8.9815e+01,  1.5480e+06],
#           [-2.4315e+05,  5.8997e+02],
#           [ 7.2124e+00,  1.4452e+06],
#           [ 4.0322e+01,  8.1466e+01],
#           [-2.8875e+02,  1.3692e+06],
#           [ 4.0027e+05,  1.5128e+03]],
#
#          [[-2.0190e+00, -5.2372e+06],
#           [ 1.0454e+07,  2.1400e+02],
#           [ 1.1165e+01,  6.0763e+02],
#           [ 5.9294e+00, -1.4099e+06],
#           [ 3.7584e+05,  2.3722e+00],
#           [ 3.3336e-01,  1.6166e+06],
#           [ 1.4068e+02, -1.8205e+02],
#           [ 2.0643e+02,  1.1582e+06]],
#
#          [[ 8.9815e+01,  1.5480e+06],
#           [ 1.1165e+01,  6.0763e+02],
#           [ 7.5692e+06,  3.2320e+03],
#           [ 4.3728e+01, -3.7970e+06],
#           [ 5.3190e+01,  3.9662e+01],
#           [-8.9091e-01,  5.5788e+03],
#           [-1.8618e+05,  4.6408e+02],
#           [-2.0391e+02, -5.3194e+04]],
#
#          [[-2.4315e+05,  5.8997e+02],
#           [ 5.9294e+00, -1.4099e+06],
#           [ 4.3728e+01, -3.7970e+06],
#           [ 7.4929e+06, -3.1905e+03],
#           [ 7.9392e-01, -8.5797e+04],
#           [-5.1432e+01, -3.2263e+00],
#           [-7.5958e+01,  9.0538e+04],
#           [ 1.7596e+05,  3.7258e+02]],
#
#          [[ 7.2124e+00,  1.4452e+06],
#           [ 3.7584e+05,  2.3722e+00],
#           [ 5.3190e+01,  3.9662e+01],
#           [ 7.9392e-01, -8.5797e+04],
#           [ 6.4348e+06, -3.5994e+01],
#           [-1.5710e+01,  3.2382e+06],
#           [-2.7439e+02, -7.0750e+02],
#           [-1.7874e+02,  1.1117e+05]],
#
#          [[ 4.0322e+01,  8.1466e+01],
#           [ 3.3336e-01,  1.6166e+06],
#           [-8.9091e-01,  5.5788e+03],
#           [-5.1432e+01, -3.2263e+00],
#           [-1.5710e+01,  3.2382e+06],
#           [ 6.3520e+06,  3.7461e+01],
#           [-1.6617e+02, -1.2594e+04],
#           [-1.6713e+02,  2.1081e+02]],
#
#          [[-2.8875e+02,  1.3692e+06],
#           [ 1.4068e+02, -1.8205e+02],
#           [-1.8618e+05,  4.6408e+02],
#           [-7.5958e+01,  9.0538e+04],
#           [-2.7439e+02, -7.0750e+02],
#           [-1.6617e+02, -1.2594e+04],
#           [ 5.3938e+06, -3.9174e+03],
#           [-1.8501e+01,  2.7514e+06]],
#
#          [[ 4.0027e+05,  1.5128e+03],
#           [ 2.0643e+02,  1.1582e+06],
#           [-2.0391e+02, -5.3194e+04],
#           [ 1.7596e+05,  3.7258e+02],
#           [-1.7874e+02,  1.1117e+05],
#           [-1.6713e+02,  2.1081e+02],
#           [-1.8501e+01,  2.7514e+06],
#           [ 5.3582e+06,  4.1126e+03]]],
#
#
#         [[[-2.2431e+02,  2.5206e+06],
#           [-5.2373e+06,  3.3042e+00],
#           [-1.5481e+06, -6.6844e+02],
#           [-6.4774e+02,  1.4769e+06],
#           [ 1.4452e+06, -3.2396e+01],
#           [ 1.1481e+01, -1.8352e+01],
#           [-1.3686e+06,  6.4851e+02],
#           [-5.6176e+02, -1.2583e+06]],
#
#          [[-5.2373e+06,  3.3042e+00],
#           [ 1.9072e+02,  2.6979e+06],
#           [ 6.6660e+02,  4.9804e+01],
#           [-1.4100e+06, -2.7644e+01],
#           [-5.1173e+01, -1.5221e+06],
#           [-1.6166e+06, -5.0332e+01],
#           [-1.4968e+03, -7.1303e+02],
#           [ 1.1572e+06, -6.2378e+02]],
#
#          [[-1.5481e+06, -6.6844e+02],
#           [ 6.6660e+02,  4.9804e+01],
#           [-3.2247e+03, -2.2666e+06],
#           [ 3.7972e+06, -2.7593e+02],
#           [ 4.0889e+01, -1.9395e+01],
#           [ 5.5590e+03, -1.9853e+00],
#           [-5.2644e+02, -3.2978e+05],
#           [ 5.3340e+04, -5.9863e+01]],
#
#          [[-6.4774e+02,  1.4769e+06],
#           [-1.4100e+06, -2.7644e+01],
#           [ 3.7972e+06, -2.7593e+02],
#           [ 3.1982e+03, -1.5663e+06],
#           [-8.5777e+04, -1.7720e+00],
#           [-2.1669e+00, -2.3048e+01],
#           [-8.8883e+04,  6.7692e+02],
#           [ 2.5505e+02, -3.7884e+05]],
#
#          [[ 1.4452e+06, -3.2396e+01],
#           [-5.1173e+01, -1.5221e+06],
#           [ 4.0889e+01, -1.9395e+01],
#           [-8.5777e+04, -1.7720e+00],
#           [ 4.0605e+01, -1.1344e+06],
#           [-3.2382e+06,  2.4154e+00],
#           [-5.8275e+02, -7.9190e+02],
#           [ 1.1119e+05, -1.3441e+02]],
#
#          [[ 1.1481e+01, -1.8352e+01],
#           [-1.6166e+06, -5.0332e+01],
#           [ 5.5590e+03, -1.9853e+00],
#           [-2.1669e+00, -2.3048e+01],
#           [-3.2382e+06,  2.4154e+00],
#           [-3.7559e+01, -2.1397e+06],
#           [-1.4188e+04, -1.6557e+02],
#           [-2.6230e+02, -1.5986e+02]],
#
#          [[-1.3686e+06,  6.4851e+02],
#           [-1.4968e+03, -7.1303e+02],
#           [-5.2644e+02, -3.2978e+05],
#           [-8.8883e+04,  6.7692e+02],
#           [-5.8275e+02, -7.9190e+02],
#           [-1.4188e+04, -1.6557e+02],
#           [ 4.0438e+03, -1.6786e+06],
#           [-2.7515e+06, -4.4291e+02]],
#
#          [[-5.6176e+02, -1.2583e+06],
#           [ 1.1572e+06, -6.2378e+02],
#           [ 5.3340e+04, -5.9863e+01],
#           [ 2.5505e+02, -3.7884e+05],
#           [ 1.1119e+05, -1.3441e+02],
#           [-2.6230e+02, -1.5986e+02],
#           [-2.7515e+06, -4.4291e+02],
#           [-3.9405e+03, -1.1380e+06]]]], dtype=torch.float64)

# %%
def merge_x(TL, TR, combine=False, trace=False):
    if trace:
        Tmerge = torch.einsum('abca,ecfe->bf', TL, TR)
    else:
        Tmerge = torch.einsum('abcd,ecfg->eabfgd', TL, TR)
        
        if combine:
            shape = Tmerge.shape
            Tmerge = Tmerge.contiguous().view(shape[0] * shape[1], shape[2], shape[3], shape[4] * shape[5])
            
    return Tmerge

def merge_x_truncate(TL, TR, dcut, niter = 10):
    if ((TL.shape[0] * TR.shape[0]) < dcut):
        return merge_x(TL, TR, True)
    Tmerge_pure = torch.einsum('abcd,ecfg,hbid,jifg->aehj', TL, TR, TL, TR)
    Tmerge_pure_shape = Tmerge_pure.shape
    Tmerge_pure = Tmerge_pure.contiguous().view(
        Tmerge_pure_shape[0] * Tmerge_pure_shape[1],Tmerge_pure_shape[2] * Tmerge_pure_shape[3]
    )
    U, S, V = torch.svd_lowrank(Tmerge_pure, q=dcut, niter=niter)
    U = U.view(Tmerge_pure_shape[0], Tmerge_pure_shape[1], dcut)
    Tmerge = torch.einsum('abcd,ecfg,aeh,dgi->hbfi', TL, TR, U, U)
    return Tmerge

# %%
temp = 2
dcut = 2

TL = get_T_bare(1/temp)
print(TL)
TL = merge_x_truncate(TL,TL,dcut)
print(TL)
TL = merge_x_truncate(TL,TL,dcut)
print(TL)
TL = merge_x_truncate(TL,TL,dcut)
print(TL)
TL = merge_x_truncate(TL,TL,dcut)
print(TL)
# Out:
# tensor([[[[2.5431, 0.0000],
#           [0.0000, 1.1752]],
#
#          [[0.0000, 1.1752],
#           [1.1752, 0.0000]]],
#
#
#         [[[0.0000, 1.1752],
#           [1.1752, 0.0000]],
#
#          [[1.1752, 0.0000],
#           [0.0000, 0.5431]]]], dtype=torch.float64)
# tensor([[[[ 6.7980e+00, -4.4055e-19],
#           [-1.6488e-19,  3.3772e+00]],
#
#          [[-9.4030e-20,  3.3772e+00],
#           [ 2.0788e+00, -1.3273e-19]]],
#
#
#         [[[-4.4055e-19,  4.3697e+00],
#           [ 3.3772e+00, -3.3500e-19]],
#
#          [[ 3.3772e+00, -3.3500e-19],
#           [-1.3273e-19,  2.0193e+00]]]], dtype=torch.float64)
# tensor([[[[ 5.0174e+01, -1.4809e-16],
#           [ 1.3685e-14,  2.5600e+01]],
#
#          [[ 1.2436e-14,  2.5600e+01],
#           [ 1.2840e+01,  1.5955e-15]]],
#
#
#         [[[-1.4809e-16,  4.1111e+01],
#           [ 2.5600e+01, -1.0312e-14]],
#
#          [[ 2.5600e+01, -1.0311e-14],
#           [ 1.5955e-15,  1.5603e+01]]]], dtype=torch.float64)
# tensor([[[[ 2.8726e+03,  3.2022e-11],
#           [-1.1500e-10,  1.5136e+03]],
#
#          [[ 1.2998e-10,  1.5136e+03],
#           [ 7.8133e+02, -1.0292e-10]]],
#
#
#         [[[ 3.2022e-11,  2.7181e+03],
#           [ 1.5136e+03, -1.7430e-10]],
#
#          [[ 1.5136e+03, -1.7433e-10],
#           [-1.0292e-10,  8.5571e+02]]]], dtype=torch.float64)
# tensor([[[[ 1.0149e+07,  3.6331e-07],
#           [-1.3301e-04,  5.4609e+06]],
#
#          [[-1.1572e-04,  5.4609e+06],
#           [ 2.9318e+06, -2.1518e-07]]],
#
#
#         [[[ 3.6331e-07,  1.0099e+07],
#           [ 5.4609e+06,  1.2422e-04]],
#
#          [[ 5.4609e+06,  1.2466e-04],
#           [-2.1518e-07,  2.9595e+06]]]], dtype=torch.float64)

# %%
TL = get_T_bare(1/temp)
print(TL)
TL = merge_x(TL,TL,True,False)
print(TL)
print(TL.shape)
# Out:
# tensor([[[[2.5431, 0.0000],
#           [0.0000, 1.1752]],
#
#          [[0.0000, 1.1752],
#           [1.1752, 0.0000]]],
#
#
#         [[[0.0000, 1.1752],
#           [1.1752, 0.0000]],
#
#          [[1.1752, 0.0000],
#           [0.0000, 0.5431]]]], dtype=torch.float64)
# tensor([[[[6.4673, 0.0000, 0.0000, 1.3811],
#           [0.0000, 1.3811, 2.9886, 0.0000]],
#
#          [[0.0000, 2.9886, 1.3811, 0.0000],
#           [1.3811, 0.0000, 0.0000, 1.3811]]],
#
#
#         [[[0.0000, 2.9886, 1.3811, 0.0000],
#           [1.3811, 0.0000, 0.0000, 1.3811]],
#
#          [[2.9886, 0.0000, 0.0000, 0.6382],
#           [0.0000, 0.6382, 1.3811, 0.0000]]],
#
#
#         [[[0.0000, 1.3811, 2.9886, 0.0000],
#           [2.9886, 0.0000, 0.0000, 0.6382]],
#
#          [[1.3811, 0.0000, 0.0000, 1.3811],
#           [0.0000, 1.3811, 0.6382, 0.0000]]],
#
#
#         [[[1.3811, 0.0000, 0.0000, 1.3811],
#           [0.0000, 1.3811, 0.6382, 0.0000]],
#
#          [[0.0000, 0.6382, 1.3811, 0.0000],
#           [1.3811, 0.0000, 0.0000, 0.2949]]]], dtype=torch.float64)
# torch.Size([4, 2, 2, 4])

# %%
# %%time
dcut = 8

for i,temp in enumerate(Temp):
    T_bare = get_T_bare(1/temp)
    TL = T_bare
    for j in range(2,MaxL+1):
        #print(j)
        TLx = merge_x_truncate(TL,TL,dcut)
        TL_Trace = merge_y(TLx,TLx,True,True)
        print(TL_Trace.shape)
        eigvals, eigvecs = torch.linalg.eigh(TL_Trace)
        W[j,i,:] = eigvals[-2:]
        TL = merge_y_truncate(TLx,TLx,dcut)
        TL = TL/torch.mean(torch.abs(TL))
E = -np.log(W)
Corr_len_2 = 1/(E[:,:,-2]-E[:,:,-1])
# Out:
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# torch.Size([4, 4])
# torch.Size([16, 16])
# torch.Size([64, 64])
# CPU times: user 1.33 s, sys: 1.07 s, total: 2.4 s
# Wall time: 470 ms
# <timed exec>:16: RuntimeWarning: divide by zero encountered in divide

# %%
# %%time

for i,temp in enumerate(Temp):
    T_bare = get_T_bare(1/temp)
    TL = T_bare
    for j in range(2,MaxL+1):
        TL_Trace = merge_y(TL,TL,True,True)
        eigvals, eigvecs = torch.linalg.eigh(TL_Trace)
        W[j,i,:] = eigvals[-2:]
        del TL_Trace
        if j != MaxL:
            TL = merge_y(TL,TL,True)
E = -np.log(W)
Corr_len = 1/(E[:,:,-2]-E[:,:,-1])
# Out:
# CPU times: user 2.27 s, sys: 1.8 s, total: 4.08 s
# Wall time: 716 ms
# <timed exec>:12: RuntimeWarning: divide by zero encountered in divide
